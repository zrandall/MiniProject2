# %%
import sys
import re
import pymongo
import json
import time
import datetime
import requests
from bs4 import BeautifulSoup

dbname = "fdac18mp2" #please use this database
collname = "glprj_zrandall" #please modify so you store data in your collection
my_char = 'a'

# beginning page index
begin = "1"
client = pymongo.MongoClient()

db = client[dbname]
coll = db[collname]


gitlab_url = "https://gitlab.com/api/v4/projects?archived=false&membership=false&order_by=created_at&owned=false&page=" + begin + \
    "&per_page=99&simple=false&sort=desc&starred=false&statistics=false&with_custom_attributes=false&with_issues_enabled=false&with_merge_requests_enabled=false"

gleft = 20

source_url = "https://sourceforge.net/directory/?q=" + my_char + "&sort=name&page="
rest_url = "https://sourceforge.net/rest/p/"

header = {'per_page': 99}

# check remaining query chances for rate-limit restriction
def wait(left):
    global header
    while (left < 20):
        l = requests.get('https://gitlab.com/api/v4/projects', headers=header)
        if (l.ok):
            left = int(l.headers.get('RateLimit-Remaining'))
        time .sleep(60)
    return left

def project_exists(url):
    r = requests.get(url)
    if r.status_code == 200:
        return True
    return False

def get_source(url, coll, rest):
    page = 1
    project_count = 0
    while True:
        resp = requests.get(url + str(page))
        text = resp.text
        soup = BeautifulSoup(text, 'html.parser')
        if re.search('No results found.', soup.get_text()):
            return

        for link in soup.find_all(class_="project-icon", href=True):
            name = re.findall('/projects/([A-Za-z0-9\-]*)', link.get('href'))
            name = name[0] if name else None
            if name is not None and name.lower().startswith(my_char):
                resp = requests.get(rest + name)
                if resp.status_code == 200:
                    info = json.loads(resp.text)
                    info['forge'] = 'sourceforge'
                    coll.insert_one(info)
                    project_count += 1
                    if project_count >= 50:
                        return
        page += 1
    return

# send queries and extract urls 
def get_gitlab(url, coll):

    global gleft
    global header
    global bginnum
    gleft = wait(gleft)
    values = []
    size = 0
    project_count = 0

    try:
        r = requests .get(url, headers=header)
        time .sleep(0.5)
        # got blocked
        if r.status_code == 403:
            return "got blocked", str(bginnum)
        if (r.ok):

            gleft = int(r.headers.get('RateLimit-Remaining'))
            lll = r.headers.get('Link')
            t = r.text
            array = json.loads(t)
            
            for el in array:
                if el['name'].lower().startswith(my_char):
                    if project_exists(el['http_url_to_repo']):
                        project_count += 1
                        el['forge'] = 'gitlab'
                        coll.insert_one(el)
                        if project_count >= 50:
                            return
            
            #next page
            while ('; rel="next"' in lll):
                gleft = int(r.headers.get('RateLimit-Remaining'))
                gleft = wait(gleft)
                # extract next page url
                ll = lll.replace(';', ',').split(',')
                url = ll[ll.index(' rel="next"') -
                         1].replace('<', '').replace('>', '').lstrip()
             
                try:
                    r = requests .get(url, headers=header)
                    if r.status_code == 403:
                        return "got blocked", str(bginnum)
                    if (r.ok):
                        lll = r.headers.get('Link')
                        t = r.text
                        array1 = json.loads(t)
                        for el in array1:
                            if el['name'].lower().startswith(my_char):
                                if project_exists(el['http_url_to_repo']):
                                    project_count += 1
                                    el['forge'] = 'gitlab'
                                    coll.insert_one(el)
                                    if project_count >= 50:
                                        return
                    else:
                        sys.stderr.write("url can not found:\n" + url + '\n')
                        return 
                except requests.exceptions.ConnectionError:
                    sys.stderr.write('could not get ' + url + '\n')
            
        else:
            sys.stderr.write("url can not found:\n" + url + '\n')
            return

    except requests.exceptions.ConnectionError:
        sys.stderr.write('could not get ' + url + '\n')
    except Exception as e:
        sys.stderr.write(url + ';' + str(e) + '\n')
        
#start retrieving        
get_gitlab(gitlab_url,coll)
get_source(source_url, coll, rest_url)
#print collected data
for doc in coll.find({}):
    print(doc)
# Out:
# {'tag_list': [], 'name': 'FTC App', 'readme_url': 'https://gitlab.com/FTC_Test/ftc_app/blob/master/README.md', 'path': 'ftc_app', 'web_url': 'https://gitlab.com/FTC_Test/ftc_app', 'forks_count': 0, 'path_with_namespace': 'FTC_Test/ftc_app', 'name_with_namespace': 'FTC_Test / FTC App', 'description': 'FTC Android Studio project to create FTC Robot Controller app. This includes source code from the 7175 Walbots that was judged as "better code than Google" by official FTC judges.', 'default_branch': 'master', 'id': 8876032, '_id': ObjectId('5bc4c8c64adcf67d12a1820d'), 'ssh_url_to_repo': 'git@gitlab.com:FTC_Test/ftc_app.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T17:02:02.806Z', 'http_url_to_repo': 'https://gitlab.com/FTC_Test/ftc_app.git', 'namespace': {'id': 3811292, 'name': 'FTC_Test', 'path': 'FTC_Test', 'full_path': 'FTC_Test', 'kind': 'group', 'parent_id': None}, 'avatar_url': 'https://assets.gitlab-static.net/uploads/-/system/project/avatar/8876032/Nico.jpg', 'last_activity_at': '2018-10-15T17:02:02.806Z'}
# {'tag_list': [], 'name': 'f', 'readme_url': None, 'path': 'f', 'web_url': 'https://gitlab.com/ngocvd/f', 'forks_count': 0, 'path_with_namespace': 'ngocvd/f', 'name_with_namespace': 'Vũ Đức Ngọc / f', 'description': None, 'default_branch': 'master', 'id': 8876011, '_id': ObjectId('5bc4c8c64adcf67d12a1820e'), 'ssh_url_to_repo': 'git@gitlab.com:ngocvd/f.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T17:01:13.391Z', 'http_url_to_repo': 'https://gitlab.com/ngocvd/f.git', 'namespace': {'id': 3772980, 'name': 'ngocvd', 'path': 'ngocvd', 'full_path': 'ngocvd', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T17:01:13.391Z'}
# {'tag_list': [], 'name': 'FIRST_COMMIT', 'readme_url': None, 'path': 'first_commit', 'web_url': 'https://gitlab.com/jaime2496333/first_commit', 'forks_count': 0, 'path_with_namespace': 'jaime2496333/first_commit', 'name_with_namespace': 'Jaime Cruz Ortega / FIRST_COMMIT', 'description': '', 'default_branch': None, 'id': 8875772, '_id': ObjectId('5bc4c8c64adcf67d12a1820f'), 'ssh_url_to_repo': 'git@gitlab.com:jaime2496333/first_commit.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T16:46:56.288Z', 'http_url_to_repo': 'https://gitlab.com/jaime2496333/first_commit.git', 'namespace': {'id': 2998469, 'name': 'jaime2496333', 'path': 'jaime2496333', 'full_path': 'jaime2496333', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T16:46:56.288Z'}
# {'tag_list': [], 'name': 'Faircoin donation widget', 'readme_url': 'https://gitlab.com/d3fc0n4/faircoin-donation-widget/blob/master/Readme.md', 'path': 'faircoin-donation-widget', 'web_url': 'https://gitlab.com/d3fc0n4/faircoin-donation-widget', 'forks_count': 0, 'path_with_namespace': 'd3fc0n4/faircoin-donation-widget', 'name_with_namespace': 'kim / Faircoin donation widget', 'description': '', 'default_branch': 'master', 'id': 8875626, '_id': ObjectId('5bc4c8c74adcf67d12a18210'), 'ssh_url_to_repo': 'git@gitlab.com:d3fc0n4/faircoin-donation-widget.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T16:35:54.526Z', 'http_url_to_repo': 'https://gitlab.com/d3fc0n4/faircoin-donation-widget.git', 'namespace': {'id': 2344673, 'name': 'd3fc0n4', 'path': 'd3fc0n4', 'full_path': 'd3fc0n4', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T16:35:54.526Z'}
# {'tag_list': [], 'name': 'FinalCalci', 'readme_url': 'https://gitlab.com/anup03gupta/FinalCalci/blob/master/README.md', 'path': 'FinalCalci', 'web_url': 'https://gitlab.com/anup03gupta/FinalCalci', 'forks_count': 0, 'path_with_namespace': 'anup03gupta/FinalCalci', 'name_with_namespace': 'Anup Gupta / FinalCalci', 'description': None, 'default_branch': 'master', 'id': 8875613, '_id': ObjectId('5bc4c8c74adcf67d12a18211'), 'ssh_url_to_repo': 'git@gitlab.com:anup03gupta/FinalCalci.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T16:34:51.146Z', 'http_url_to_repo': 'https://gitlab.com/anup03gupta/FinalCalci.git', 'namespace': {'id': 3760154, 'name': 'anup03gupta', 'path': 'anup03gupta', 'full_path': 'anup03gupta', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T16:34:51.146Z'}
# {'tag_list': [], 'name': 'frontend_pec1', 'readme_url': 'https://gitlab.com/misubirana/frontend_pec1/blob/master/README.md', 'path': 'frontend_pec1', 'web_url': 'https://gitlab.com/misubirana/frontend_pec1', 'forks_count': 0, 'path_with_namespace': 'misubirana/frontend_pec1', 'name_with_namespace': 'Mireia Subirana Gimenez / frontend_pec1', 'description': 'Primera práctica de desarrollo frontend', 'default_branch': 'master', 'id': 8875561, '_id': ObjectId('5bc4c8c74adcf67d12a18212'), 'ssh_url_to_repo': 'git@gitlab.com:misubirana/frontend_pec1.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T16:30:25.439Z', 'http_url_to_repo': 'https://gitlab.com/misubirana/frontend_pec1.git', 'namespace': {'id': 3810972, 'name': 'misubirana', 'path': 'misubirana', 'full_path': 'misubirana', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T16:30:25.439Z'}
# {'tag_list': [], 'name': 'FE Sesi 7', 'readme_url': 'https://gitlab.com/mars_/fe-sesi-7/blob/master/README.md', 'path': 'fe-sesi-7', 'web_url': 'https://gitlab.com/mars_/fe-sesi-7', 'forks_count': 0, 'path_with_namespace': 'mars_/fe-sesi-7', 'name_with_namespace': 'Mars Santoso / FE Sesi 7', 'description': '', 'default_branch': 'master', 'id': 8875240, '_id': ObjectId('5bc4c8cc4adcf67d12a18213'), 'ssh_url_to_repo': 'git@gitlab.com:mars_/fe-sesi-7.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T16:08:36.552Z', 'http_url_to_repo': 'https://gitlab.com/mars_/fe-sesi-7.git', 'namespace': {'id': 835133, 'name': 'mars_', 'path': 'mars_', 'full_path': 'mars_', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T16:08:36.552Z'}
# {'tag_list': [], 'name': 'File system dockerfile', 'readme_url': 'https://gitlab.com/ognarb/fs-docker/blob/master/README.md', 'path': 'fs-docker', 'web_url': 'https://gitlab.com/ognarb/fs-docker', 'forks_count': 0, 'path_with_namespace': 'ognarb/fs-docker', 'name_with_namespace': 'Schwan Carl / File system dockerfile', 'description': '', 'default_branch': 'master', 'id': 8875130, '_id': ObjectId('5bc4c8cc4adcf67d12a18214'), 'ssh_url_to_repo': 'git@gitlab.com:ognarb/fs-docker.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T16:00:43.328Z', 'http_url_to_repo': 'https://gitlab.com/ognarb/fs-docker.git', 'namespace': {'id': 2026150, 'name': 'ognarb', 'path': 'ognarb', 'full_path': 'ognarb', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T16:00:43.328Z'}
# {'tag_list': [], 'name': 'finedust', 'readme_url': None, 'path': 'finedust', 'web_url': 'https://gitlab.com/jie88min/finedust', 'forks_count': 0, 'path_with_namespace': 'jie88min/finedust', 'name_with_namespace': 'KimJiMin / finedust', 'description': '공기어때', 'default_branch': 'master', 'id': 8875015, '_id': ObjectId('5bc4c8cd4adcf67d12a18215'), 'ssh_url_to_repo': 'git@gitlab.com:jie88min/finedust.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T15:53:42.422Z', 'http_url_to_repo': 'https://gitlab.com/jie88min/finedust.git', 'namespace': {'id': 2256976, 'name': 'jie88min', 'path': 'jie88min', 'full_path': 'jie88min', 'kind': 'user', 'parent_id': None}, 'avatar_url': 'https://assets.gitlab-static.net/uploads/-/system/project/avatar/8875015/ic_launcher_round-web.png', 'last_activity_at': '2018-10-15T15:53:42.422Z'}
# {'tag_list': [], 'name': 'First Kaiju', 'readme_url': 'https://gitlab.com/Christopher2K/first-kaiju/blob/master/README.md', 'path': 'first-kaiju', 'web_url': 'https://gitlab.com/Christopher2K/first-kaiju', 'forks_count': 0, 'path_with_namespace': 'Christopher2K/first-kaiju', 'name_with_namespace': 'Christopher N. KATOYI / First Kaiju', 'description': 'Kaiju first project', 'default_branch': 'master', 'id': 8874861, '_id': ObjectId('5bc4c8cd4adcf67d12a18216'), 'ssh_url_to_repo': 'git@gitlab.com:Christopher2K/first-kaiju.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T15:43:35.198Z', 'http_url_to_repo': 'https://gitlab.com/Christopher2K/first-kaiju.git', 'namespace': {'id': 1569066, 'name': 'Christopher2K', 'path': 'Christopher2K', 'full_path': 'Christopher2K', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T15:43:35.198Z'}
# {'tag_list': [], 'name': 'FsFirestore', 'readme_url': 'https://gitlab.com/mrbandler/FsFirestore/blob/master/README.md', 'path': 'FsFirestore', 'web_url': 'https://gitlab.com/mrbandler/FsFirestore', 'forks_count': 0, 'path_with_namespace': 'mrbandler/FsFirestore', 'name_with_namespace': 'mrbandler / FsFirestore', 'description': 'Functional F# library to access Firestore database via Google Cloud Platform (GCP) or Firebase Project.', 'default_branch': 'master', 'id': 8874129, '_id': ObjectId('5bc4c8da4adcf67d12a18217'), 'ssh_url_to_repo': 'git@gitlab.com:mrbandler/FsFirestore.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T14:59:17.091Z', 'http_url_to_repo': 'https://gitlab.com/mrbandler/FsFirestore.git', 'namespace': {'id': 196229, 'name': 'mrbandler', 'path': 'mrbandler', 'full_path': 'mrbandler', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T14:59:17.091Z'}
# {'tag_list': [], 'name': 'fml.atmoscraft_advanced', 'readme_url': 'https://gitlab.com/nullexcept1on/fml.atmoscraft_advanced/blob/master/README.md', 'path': 'fml.atmoscraft_advanced', 'web_url': 'https://gitlab.com/nullexcept1on/fml.atmoscraft_advanced', 'forks_count': 0, 'path_with_namespace': 'nullexcept1on/fml.atmoscraft_advanced', 'name_with_namespace': 'NullException / fml.atmoscraft_advanced', 'description': '', 'default_branch': 'master', 'id': 8874110, '_id': ObjectId('5bc4c8db4adcf67d12a18218'), 'ssh_url_to_repo': 'git@gitlab.com:nullexcept1on/fml.atmoscraft_advanced.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T14:58:04.674Z', 'http_url_to_repo': 'https://gitlab.com/nullexcept1on/fml.atmoscraft_advanced.git', 'namespace': {'id': 2504846, 'name': 'nullexcept1on', 'path': 'nullexcept1on', 'full_path': 'nullexcept1on', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T16:06:59.642Z'}
# {'tag_list': [], 'name': 'frontend.crm', 'readme_url': 'https://gitlab.com/trungntm/frontend.crm/blob/master/README.md', 'path': 'frontend.crm', 'web_url': 'https://gitlab.com/trungntm/frontend.crm', 'forks_count': 0, 'path_with_namespace': 'trungntm/frontend.crm', 'name_with_namespace': 'Nguyáť\x85n TáşĄ Minh Trung / frontend.crm', 'description': '', 'default_branch': 'master', 'id': 8873606, '_id': ObjectId('5bc4c8e54adcf67d12a18219'), 'ssh_url_to_repo': 'git@gitlab.com:trungntm/frontend.crm.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T14:39:56.833Z', 'http_url_to_repo': 'https://gitlab.com/trungntm/frontend.crm.git', 'namespace': {'id': 3715658, 'name': 'trungntm', 'path': 'trungntm', 'full_path': 'trungntm', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T14:39:56.833Z'}
# {'tag_list': ['.NET', 'API', 'Autodesk', 'C#', 'Forge', 'JS', 'architecture', 'automation', 'construction', 'design'], 'name': 'forge-automation', 'readme_url': 'https://gitlab.com/mitevpi/forge-api-nodejs/blob/master/README.md', 'path': 'forge-api-nodejs', 'web_url': 'https://gitlab.com/mitevpi/forge-api-nodejs', 'forks_count': 0, 'path_with_namespace': 'mitevpi/forge-api-nodejs', 'name_with_namespace': 'Petr Mitev / forge-automation', 'description': "POC for leveraging Autodesk's Forge API for automating typical project/model management tasks in BIM360.", 'default_branch': 'master', 'id': 8873452, '_id': ObjectId('5bc4c8e54adcf67d12a1821a'), 'ssh_url_to_repo': 'git@gitlab.com:mitevpi/forge-api-nodejs.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T14:33:01.057Z', 'http_url_to_repo': 'https://gitlab.com/mitevpi/forge-api-nodejs.git', 'namespace': {'id': 2971983, 'name': 'mitevpi', 'path': 'mitevpi', 'full_path': 'mitevpi', 'kind': 'user', 'parent_id': None}, 'avatar_url': 'https://assets.gitlab-static.net/uploads/-/system/project/avatar/8873452/forge-logo.png', 'last_activity_at': '2018-10-15T14:33:01.057Z'}
# {'tag_list': [], 'name': 'find3r', 'readme_url': None, 'path': 'find3r', 'web_url': 'https://gitlab.com/TomEliott/find3r', 'forks_count': 0, 'path_with_namespace': 'TomEliott/find3r', 'name_with_namespace': 'Find3r / find3r', 'description': '', 'default_branch': 'master', 'id': 8873409, '_id': ObjectId('5bc4c8e54adcf67d12a1821b'), 'ssh_url_to_repo': 'git@gitlab.com:TomEliott/find3r.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T14:31:08.086Z', 'http_url_to_repo': 'https://gitlab.com/TomEliott/find3r.git', 'namespace': {'id': 2124134, 'name': 'TomEliott', 'path': 'TomEliott', 'full_path': 'TomEliott', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T14:31:08.086Z'}
# {'tag_list': [], 'name': 'Finite Run', 'readme_url': 'https://gitlab.com/juhis2000/finite-run/blob/master/README.md', 'path': 'finite-run', 'web_url': 'https://gitlab.com/juhis2000/finite-run', 'forks_count': 0, 'path_with_namespace': 'juhis2000/finite-run', 'name_with_namespace': 'Juha-Pekka Asikainen / Finite Run', 'description': '', 'default_branch': 'master', 'id': 8873098, '_id': ObjectId('5bc4c8ea4adcf67d12a1821c'), 'ssh_url_to_repo': 'git@gitlab.com:juhis2000/finite-run.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T14:15:22.702Z', 'http_url_to_repo': 'https://gitlab.com/juhis2000/finite-run.git', 'namespace': {'id': 3806315, 'name': 'juhis2000', 'path': 'juhis2000', 'full_path': 'juhis2000', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T14:15:22.702Z'}
# {'tag_list': [], 'name': 'Flappy Bird - Phaser', 'readme_url': 'https://gitlab.com/diego.ramirez/flappy-bird-phaser/blob/master/README.md', 'path': 'flappy-bird-phaser', 'web_url': 'https://gitlab.com/diego.ramirez/flappy-bird-phaser', 'forks_count': 0, 'path_with_namespace': 'diego.ramirez/flappy-bird-phaser', 'name_with_namespace': 'Diego Ramirez / Flappy Bird - Phaser', 'description': '', 'default_branch': 'master', 'id': 8872588, '_id': ObjectId('5bc4c8ee4adcf67d12a1821d'), 'ssh_url_to_repo': 'git@gitlab.com:diego.ramirez/flappy-bird-phaser.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T13:56:04.823Z', 'http_url_to_repo': 'https://gitlab.com/diego.ramirez/flappy-bird-phaser.git', 'namespace': {'id': 2421825, 'name': 'diego.ramirez', 'path': 'diego.ramirez', 'full_path': 'diego.ramirez', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T16:45:52.536Z'}
# {'tag_list': [], 'name': 'frontend-assessment-full-app-in-express', 'readme_url': 'https://gitlab.com/jayaimzzz/frontend-assessment-full-app-in-express/blob/master/README.md', 'path': 'frontend-assessment-full-app-in-express', 'web_url': 'https://gitlab.com/jayaimzzz/frontend-assessment-full-app-in-express', 'forks_count': 0, 'path_with_namespace': 'jayaimzzz/frontend-assessment-full-app-in-express', 'name_with_namespace': 'James Horton / frontend-assessment-full-app-in-express', 'description': None, 'default_branch': 'master', 'id': 8872362, '_id': ObjectId('5bc4c8f44adcf67d12a1821e'), 'ssh_url_to_repo': 'git@gitlab.com:jayaimzzz/frontend-assessment-full-app-in-express.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T13:41:31.106Z', 'http_url_to_repo': 'https://gitlab.com/jayaimzzz/frontend-assessment-full-app-in-express.git', 'namespace': {'id': 3627752, 'name': 'jayaimzzz', 'path': 'jayaimzzz', 'full_path': 'jayaimzzz', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T13:41:31.106Z'}
# {'tag_list': [], 'name': 'foodie', 'readme_url': 'https://gitlab.com/andrea/foodie/blob/master/README.md', 'path': 'foodie', 'web_url': 'https://gitlab.com/andrea/foodie', 'forks_count': 0, 'path_with_namespace': 'andrea/foodie', 'name_with_namespace': 'Andrea Di Marco / foodie', 'description': 'A React/Node recipe management application.', 'default_branch': 'master', 'id': 8871855, '_id': ObjectId('5bc4c8f94adcf67d12a1821f'), 'ssh_url_to_repo': 'git@gitlab.com:andrea/foodie.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T13:16:39.287Z', 'http_url_to_repo': 'https://gitlab.com/andrea/foodie.git', 'namespace': {'id': 438, 'name': 'andrea', 'path': 'andrea', 'full_path': 'andrea', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T13:16:39.287Z'}
# {'tag_list': [], 'name': 'Final Calculator', 'readme_url': 'https://gitlab.com/shraddhasable/Final-Calculator/blob/master/README.md', 'path': 'Final-Calculator', 'web_url': 'https://gitlab.com/shraddhasable/Final-Calculator', 'forks_count': 0, 'path_with_namespace': 'shraddhasable/Final-Calculator', 'name_with_namespace': 'shraddha / Final Calculator', 'description': '', 'default_branch': 'master', 'id': 8871238, '_id': ObjectId('5bc4c8fe4adcf67d12a18220'), 'ssh_url_to_repo': 'git@gitlab.com:shraddhasable/Final-Calculator.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T12:41:50.968Z', 'http_url_to_repo': 'https://gitlab.com/shraddhasable/Final-Calculator.git', 'namespace': {'id': 3688266, 'name': 'shraddhasable', 'path': 'shraddhasable', 'full_path': 'shraddhasable', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T14:01:17.744Z'}
# {'tag_list': [], 'name': 'FSU', 'readme_url': 'https://gitlab.com/Unifyed/kryptosmobile/FSU/blob/master/README.md', 'path': 'FSU', 'web_url': 'https://gitlab.com/Unifyed/kryptosmobile/FSU', 'forks_count': 0, 'path_with_namespace': 'Unifyed/kryptosmobile/FSU', 'name_with_namespace': 'Unifyed / kryptosmobile / FSU', 'description': 'FSU Mobile app powered by Kryptos', 'default_branch': 'master', 'id': 8871123, '_id': ObjectId('5bc4c9024adcf67d12a18221'), 'ssh_url_to_repo': 'git@gitlab.com:Unifyed/kryptosmobile/FSU.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T12:36:22.265Z', 'http_url_to_repo': 'https://gitlab.com/Unifyed/kryptosmobile/FSU.git', 'namespace': {'id': 3592994, 'name': 'kryptosmobile', 'path': 'kryptosmobile', 'full_path': 'Unifyed/kryptosmobile', 'kind': 'group', 'parent_id': 1446686}, 'avatar_url': None, 'last_activity_at': '2018-10-15T12:36:22.265Z'}
# {'tag_list': [], 'name': 'FSM', 'readme_url': 'https://gitlab.com/Unifyed/kryptosmobile/FSM/blob/master/README.md', 'path': 'FSM', 'web_url': 'https://gitlab.com/Unifyed/kryptosmobile/FSM', 'forks_count': 0, 'path_with_namespace': 'Unifyed/kryptosmobile/FSM', 'name_with_namespace': 'Unifyed / kryptosmobile / FSM', 'description': None, 'default_branch': 'master', 'id': 8871119, '_id': ObjectId('5bc4c9034adcf67d12a18222'), 'ssh_url_to_repo': 'git@gitlab.com:Unifyed/kryptosmobile/FSM.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T12:36:17.127Z', 'http_url_to_repo': 'https://gitlab.com/Unifyed/kryptosmobile/FSM.git', 'namespace': {'id': 3592994, 'name': 'kryptosmobile', 'path': 'kryptosmobile', 'full_path': 'Unifyed/kryptosmobile', 'kind': 'group', 'parent_id': 1446686}, 'avatar_url': None, 'last_activity_at': '2018-10-15T12:36:17.127Z'}
# {'tag_list': [], 'name': 'FrostBurg', 'readme_url': 'https://gitlab.com/Unifyed/kryptosmobile/FrostBurg/blob/master/README.md', 'path': 'FrostBurg', 'web_url': 'https://gitlab.com/Unifyed/kryptosmobile/FrostBurg', 'forks_count': 0, 'path_with_namespace': 'Unifyed/kryptosmobile/FrostBurg', 'name_with_namespace': 'Unifyed / kryptosmobile / FrostBurg', 'description': None, 'default_branch': 'master', 'id': 8870952, '_id': ObjectId('5bc4c9034adcf67d12a18223'), 'ssh_url_to_repo': 'git@gitlab.com:Unifyed/kryptosmobile/FrostBurg.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T12:29:18.082Z', 'http_url_to_repo': 'https://gitlab.com/Unifyed/kryptosmobile/FrostBurg.git', 'namespace': {'id': 3592994, 'name': 'kryptosmobile', 'path': 'kryptosmobile', 'full_path': 'Unifyed/kryptosmobile', 'kind': 'group', 'parent_id': 1446686}, 'avatar_url': None, 'last_activity_at': '2018-10-15T12:29:18.082Z'}
# {'tag_list': [], 'name': 'FreeChargeWallet', 'readme_url': 'https://gitlab.com/Unifyed/kryptosmobile/FreeChargeWallet/blob/master/README.md', 'path': 'FreeChargeWallet', 'web_url': 'https://gitlab.com/Unifyed/kryptosmobile/FreeChargeWallet', 'forks_count': 0, 'path_with_namespace': 'Unifyed/kryptosmobile/FreeChargeWallet', 'name_with_namespace': 'Unifyed / kryptosmobile / FreeChargeWallet', 'description': 'FreeChargeWallet', 'default_branch': 'master', 'id': 8870949, '_id': ObjectId('5bc4c9034adcf67d12a18224'), 'ssh_url_to_repo': 'git@gitlab.com:Unifyed/kryptosmobile/FreeChargeWallet.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T12:29:11.436Z', 'http_url_to_repo': 'https://gitlab.com/Unifyed/kryptosmobile/FreeChargeWallet.git', 'namespace': {'id': 3592994, 'name': 'kryptosmobile', 'path': 'kryptosmobile', 'full_path': 'Unifyed/kryptosmobile', 'kind': 'group', 'parent_id': 1446686}, 'avatar_url': None, 'last_activity_at': '2018-10-15T12:29:11.436Z'}
# {'tag_list': [], 'name': 'FOTE', 'readme_url': 'https://gitlab.com/Unifyed/kryptosmobile/FOTE/blob/master/README.md', 'path': 'FOTE', 'web_url': 'https://gitlab.com/Unifyed/kryptosmobile/FOTE', 'forks_count': 0, 'path_with_namespace': 'Unifyed/kryptosmobile/FOTE', 'name_with_namespace': 'Unifyed / kryptosmobile / FOTE', 'description': None, 'default_branch': 'master', 'id': 8870947, '_id': ObjectId('5bc4c9044adcf67d12a18225'), 'ssh_url_to_repo': 'git@gitlab.com:Unifyed/kryptosmobile/FOTE.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T12:29:05.950Z', 'http_url_to_repo': 'https://gitlab.com/Unifyed/kryptosmobile/FOTE.git', 'namespace': {'id': 3592994, 'name': 'kryptosmobile', 'path': 'kryptosmobile', 'full_path': 'Unifyed/kryptosmobile', 'kind': 'group', 'parent_id': 1446686}, 'avatar_url': None, 'last_activity_at': '2018-10-15T12:29:05.950Z'}
# {'tag_list': [], 'name': 'Forum', 'readme_url': 'https://gitlab.com/Unifyed/kryptosmobile/Forum/blob/master/README.md', 'path': 'Forum', 'web_url': 'https://gitlab.com/Unifyed/kryptosmobile/Forum', 'forks_count': 0, 'path_with_namespace': 'Unifyed/kryptosmobile/Forum', 'name_with_namespace': 'Unifyed / kryptosmobile / Forum', 'description': 'CIU Forum Applet', 'default_branch': 'master', 'id': 8870943, '_id': ObjectId('5bc4c9044adcf67d12a18226'), 'ssh_url_to_repo': 'git@gitlab.com:Unifyed/kryptosmobile/Forum.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T12:28:59.012Z', 'http_url_to_repo': 'https://gitlab.com/Unifyed/kryptosmobile/Forum.git', 'namespace': {'id': 3592994, 'name': 'kryptosmobile', 'path': 'kryptosmobile', 'full_path': 'Unifyed/kryptosmobile', 'kind': 'group', 'parent_id': 1446686}, 'avatar_url': None, 'last_activity_at': '2018-10-15T12:28:59.012Z'}
# {'tag_list': [], 'name': 'Focusvce', 'readme_url': 'https://gitlab.com/Unifyed/kryptosmobile/Focusvce/blob/master/README.md', 'path': 'Focusvce', 'web_url': 'https://gitlab.com/Unifyed/kryptosmobile/Focusvce', 'forks_count': 0, 'path_with_namespace': 'Unifyed/kryptosmobile/Focusvce', 'name_with_namespace': 'Unifyed / kryptosmobile / Focusvce', 'description': None, 'default_branch': 'master', 'id': 8870939, '_id': ObjectId('5bc4c9044adcf67d12a18227'), 'ssh_url_to_repo': 'git@gitlab.com:Unifyed/kryptosmobile/Focusvce.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T12:28:49.219Z', 'http_url_to_repo': 'https://gitlab.com/Unifyed/kryptosmobile/Focusvce.git', 'namespace': {'id': 3592994, 'name': 'kryptosmobile', 'path': 'kryptosmobile', 'full_path': 'Unifyed/kryptosmobile', 'kind': 'group', 'parent_id': 1446686}, 'avatar_url': None, 'last_activity_at': '2018-10-15T12:28:49.219Z'}
# {'tag_list': [], 'name': 'FOCS', 'readme_url': 'https://gitlab.com/Unifyed/kryptosmobile/FOCS/blob/master/README.md', 'path': 'FOCS', 'web_url': 'https://gitlab.com/Unifyed/kryptosmobile/FOCS', 'forks_count': 0, 'path_with_namespace': 'Unifyed/kryptosmobile/FOCS', 'name_with_namespace': 'Unifyed / kryptosmobile / FOCS', 'description': 'Department of Computer Science-University of Delhi', 'default_branch': 'master', 'id': 8870938, '_id': ObjectId('5bc4c9054adcf67d12a18228'), 'ssh_url_to_repo': 'git@gitlab.com:Unifyed/kryptosmobile/FOCS.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T12:28:45.296Z', 'http_url_to_repo': 'https://gitlab.com/Unifyed/kryptosmobile/FOCS.git', 'namespace': {'id': 3592994, 'name': 'kryptosmobile', 'path': 'kryptosmobile', 'full_path': 'Unifyed/kryptosmobile', 'kind': 'group', 'parent_id': 1446686}, 'avatar_url': None, 'last_activity_at': '2018-10-15T12:28:45.296Z'}
# {'tag_list': [], 'name': 'firstapp', 'readme_url': None, 'path': 'firstapp', 'web_url': 'https://gitlab.com/Unifyed/kryptosmobile/firstapp', 'forks_count': 0, 'path_with_namespace': 'Unifyed/kryptosmobile/firstapp', 'name_with_namespace': 'Unifyed / kryptosmobile / firstapp', 'description': 'my first appp', 'default_branch': None, 'id': 8870934, '_id': ObjectId('5bc4c9054adcf67d12a18229'), 'ssh_url_to_repo': 'git@gitlab.com:Unifyed/kryptosmobile/firstapp.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T12:28:41.375Z', 'http_url_to_repo': 'https://gitlab.com/Unifyed/kryptosmobile/firstapp.git', 'namespace': {'id': 3592994, 'name': 'kryptosmobile', 'path': 'kryptosmobile', 'full_path': 'Unifyed/kryptosmobile', 'kind': 'group', 'parent_id': 1446686}, 'avatar_url': None, 'last_activity_at': '2018-10-15T12:28:41.375Z'}
# {'tag_list': [], 'name': 'FMG', 'readme_url': 'https://gitlab.com/Unifyed/kryptosmobile/FMG/blob/master/README.md', 'path': 'FMG', 'web_url': 'https://gitlab.com/Unifyed/kryptosmobile/FMG', 'forks_count': 0, 'path_with_namespace': 'Unifyed/kryptosmobile/FMG', 'name_with_namespace': 'Unifyed / kryptosmobile / FMG', 'description': None, 'default_branch': 'master', 'id': 8870932, '_id': ObjectId('5bc4c9054adcf67d12a1822a'), 'ssh_url_to_repo': 'git@gitlab.com:Unifyed/kryptosmobile/FMG.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T12:28:38.065Z', 'http_url_to_repo': 'https://gitlab.com/Unifyed/kryptosmobile/FMG.git', 'namespace': {'id': 3592994, 'name': 'kryptosmobile', 'path': 'kryptosmobile', 'full_path': 'Unifyed/kryptosmobile', 'kind': 'group', 'parent_id': 1446686}, 'avatar_url': None, 'last_activity_at': '2018-10-15T12:28:38.065Z'}
# {'tag_list': [], 'name': 'Felician-University', 'readme_url': 'https://gitlab.com/Unifyed/kryptosmobile/Felician-University/blob/master/README.md', 'path': 'Felician-University', 'web_url': 'https://gitlab.com/Unifyed/kryptosmobile/Felician-University', 'forks_count': 0, 'path_with_namespace': 'Unifyed/kryptosmobile/Felician-University', 'name_with_namespace': 'Unifyed / kryptosmobile / Felician-University', 'description': 'Felician University', 'default_branch': 'master', 'id': 8870929, '_id': ObjectId('5bc4c9064adcf67d12a1822b'), 'ssh_url_to_repo': 'git@gitlab.com:Unifyed/kryptosmobile/Felician-University.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T12:28:34.943Z', 'http_url_to_repo': 'https://gitlab.com/Unifyed/kryptosmobile/Felician-University.git', 'namespace': {'id': 3592994, 'name': 'kryptosmobile', 'path': 'kryptosmobile', 'full_path': 'Unifyed/kryptosmobile', 'kind': 'group', 'parent_id': 1446686}, 'avatar_url': None, 'last_activity_at': '2018-10-15T12:28:34.943Z'}
# {'tag_list': [], 'name': 'First', 'readme_url': None, 'path': 'First', 'web_url': 'https://gitlab.com/fangjiangfeng/First', 'forks_count': 0, 'path_with_namespace': 'fangjiangfeng/First', 'name_with_namespace': 'fangjiangfeng / First', 'description': None, 'default_branch': 'master', 'id': 8870656, '_id': ObjectId('5bc4c90a4adcf67d12a1822c'), 'ssh_url_to_repo': 'git@gitlab.com:fangjiangfeng/First.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T12:11:13.642Z', 'http_url_to_repo': 'https://gitlab.com/fangjiangfeng/First.git', 'namespace': {'id': 3808964, 'name': 'fangjiangfeng', 'path': 'fangjiangfeng', 'full_path': 'fangjiangfeng', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T12:11:13.642Z'}
# {'tag_list': [], 'name': 'FTC App', 'readme_url': 'https://gitlab.com/Personal-practice/ftc_app/blob/master/README.md', 'path': 'ftc_app', 'web_url': 'https://gitlab.com/Personal-practice/ftc_app', 'forks_count': 0, 'path_with_namespace': 'Personal-practice/ftc_app', 'name_with_namespace': 'Personal practice / FTC App', 'description': 'FTC Android Studio project to create FTC Robot Controller app. This includes source code from the 7175 Walbots that was judged as "better code than Google" by official FTC judges.', 'default_branch': 'master', 'id': 8870314, '_id': ObjectId('5bc4c90b4adcf67d12a1822d'), 'ssh_url_to_repo': 'git@gitlab.com:Personal-practice/ftc_app.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T11:49:10.825Z', 'http_url_to_repo': 'https://gitlab.com/Personal-practice/ftc_app.git', 'namespace': {'id': 3809050, 'name': 'Personal practice', 'path': 'Personal-practice', 'full_path': 'Personal-practice', 'kind': 'group', 'parent_id': None}, 'avatar_url': 'https://assets.gitlab-static.net/uploads/-/system/project/avatar/8870314/Nico.jpg', 'last_activity_at': '2018-10-15T11:49:10.825Z'}
# {'tag_list': [], 'name': 'Fee-payment', 'readme_url': 'https://gitlab.com/Unifyed/kryptosmobile/Fee-payment/blob/master/README.md', 'path': 'Fee-payment', 'web_url': 'https://gitlab.com/Unifyed/kryptosmobile/Fee-payment', 'forks_count': 0, 'path_with_namespace': 'Unifyed/kryptosmobile/Fee-payment', 'name_with_namespace': 'Unifyed / kryptosmobile / Fee-payment', 'description': 'Fee payment Dashboard and Mobile APIs', 'default_branch': 'master', 'id': 8870276, '_id': ObjectId('5bc4c90b4adcf67d12a1822e'), 'ssh_url_to_repo': 'git@gitlab.com:Unifyed/kryptosmobile/Fee-payment.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T11:46:48.389Z', 'http_url_to_repo': 'https://gitlab.com/Unifyed/kryptosmobile/Fee-payment.git', 'namespace': {'id': 3592994, 'name': 'kryptosmobile', 'path': 'kryptosmobile', 'full_path': 'Unifyed/kryptosmobile', 'kind': 'group', 'parent_id': 1446686}, 'avatar_url': None, 'last_activity_at': '2018-10-15T11:46:48.389Z'}
# {'tag_list': [], 'name': 'FCMerchant', 'readme_url': 'https://gitlab.com/Unifyed/kryptosmobile/FCMerchant/blob/master/README.md', 'path': 'FCMerchant', 'web_url': 'https://gitlab.com/Unifyed/kryptosmobile/FCMerchant', 'forks_count': 0, 'path_with_namespace': 'Unifyed/kryptosmobile/FCMerchant', 'name_with_namespace': 'Unifyed / kryptosmobile / FCMerchant', 'description': None, 'default_branch': 'master', 'id': 8870269, '_id': ObjectId('5bc4c9134adcf67d12a1822f'), 'ssh_url_to_repo': 'git@gitlab.com:Unifyed/kryptosmobile/FCMerchant.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T11:46:41.813Z', 'http_url_to_repo': 'https://gitlab.com/Unifyed/kryptosmobile/FCMerchant.git', 'namespace': {'id': 3592994, 'name': 'kryptosmobile', 'path': 'kryptosmobile', 'full_path': 'Unifyed/kryptosmobile', 'kind': 'group', 'parent_id': 1446686}, 'avatar_url': None, 'last_activity_at': '2018-10-15T11:46:41.813Z'}
# {'tag_list': [], 'name': 'FDMUBIN', 'readme_url': 'https://gitlab.com/Unifyed/kryptosmobile/FDMUBIN/blob/master/README.md', 'path': 'FDMUBIN', 'web_url': 'https://gitlab.com/Unifyed/kryptosmobile/FDMUBIN', 'forks_count': 0, 'path_with_namespace': 'Unifyed/kryptosmobile/FDMUBIN', 'name_with_namespace': 'Unifyed / kryptosmobile / FDMUBIN', 'description': None, 'default_branch': 'master', 'id': 8870267, '_id': ObjectId('5bc4c9144adcf67d12a18230'), 'ssh_url_to_repo': 'git@gitlab.com:Unifyed/kryptosmobile/FDMUBIN.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T11:46:39.696Z', 'http_url_to_repo': 'https://gitlab.com/Unifyed/kryptosmobile/FDMUBIN.git', 'namespace': {'id': 3592994, 'name': 'kryptosmobile', 'path': 'kryptosmobile', 'full_path': 'Unifyed/kryptosmobile', 'kind': 'group', 'parent_id': 1446686}, 'avatar_url': None, 'last_activity_at': '2018-10-15T11:46:39.696Z'}
# {'tag_list': [], 'name': 'Fairfield-University', 'readme_url': 'https://gitlab.com/Unifyed/kryptosmobile/Fairfield-University/blob/master/README.md', 'path': 'Fairfield-University', 'web_url': 'https://gitlab.com/Unifyed/kryptosmobile/Fairfield-University', 'forks_count': 0, 'path_with_namespace': 'Unifyed/kryptosmobile/Fairfield-University', 'name_with_namespace': 'Unifyed / kryptosmobile / Fairfield-University', 'description': 'Fairfield University', 'default_branch': 'master', 'id': 8870265, '_id': ObjectId('5bc4c9144adcf67d12a18231'), 'ssh_url_to_repo': 'git@gitlab.com:Unifyed/kryptosmobile/Fairfield-University.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T11:46:33.972Z', 'http_url_to_repo': 'https://gitlab.com/Unifyed/kryptosmobile/Fairfield-University.git', 'namespace': {'id': 3592994, 'name': 'kryptosmobile', 'path': 'kryptosmobile', 'full_path': 'Unifyed/kryptosmobile', 'kind': 'group', 'parent_id': 1446686}, 'avatar_url': None, 'last_activity_at': '2018-10-15T11:46:33.972Z'}
# {'tag_list': [], 'name': 'FSTree', 'readme_url': 'https://gitlab.com/karanrajpal14/FSTree/blob/master/README.md', 'path': 'FSTree', 'web_url': 'https://gitlab.com/karanrajpal14/FSTree', 'forks_count': 0, 'path_with_namespace': 'karanrajpal14/FSTree', 'name_with_namespace': 'Karan Rajpal / FSTree', 'description': 'A script to keep track of my file-system', 'default_branch': 'master', 'id': 8868678, '_id': ObjectId('5bc4c9274adcf67d12a18232'), 'ssh_url_to_repo': 'git@gitlab.com:karanrajpal14/FSTree.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T10:23:23.517Z', 'http_url_to_repo': 'https://gitlab.com/karanrajpal14/FSTree.git', 'namespace': {'id': 289074, 'name': 'karanrajpal14', 'path': 'karanrajpal14', 'full_path': 'karanrajpal14', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T10:23:23.517Z'}
# {'tag_list': [], 'name': 'farsi corpus', 'readme_url': 'https://gitlab.com/samaritan21/farsi-corpus/blob/master/README.md', 'path': 'farsi-corpus', 'web_url': 'https://gitlab.com/samaritan21/farsi-corpus', 'forks_count': 0, 'path_with_namespace': 'samaritan21/farsi-corpus', 'name_with_namespace': 'Amir Hossein Azizi / farsi corpus', 'description': 'This code finds the lemma for each word in the Uppsala Persian Corpus (UPC)', 'default_branch': 'master', 'id': 8868369, '_id': ObjectId('5bc4c9284adcf67d12a18233'), 'ssh_url_to_repo': 'git@gitlab.com:samaritan21/farsi-corpus.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T10:02:40.444Z', 'http_url_to_repo': 'https://gitlab.com/samaritan21/farsi-corpus.git', 'namespace': {'id': 503781, 'name': 'samaritan21', 'path': 'samaritan21', 'full_path': 'samaritan21', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T10:02:40.444Z'}
# {'tag_list': [], 'name': 'fwt', 'readme_url': None, 'path': 'fwt', 'web_url': 'https://gitlab.com/fjy123/fwt', 'forks_count': 0, 'path_with_namespace': 'fjy123/fwt', 'name_with_namespace': 'fjy / fwt', 'description': '', 'default_branch': 'master', 'id': 8868328, '_id': ObjectId('5bc4c9284adcf67d12a18234'), 'ssh_url_to_repo': 'git@gitlab.com:fjy123/fwt.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T09:59:31.627Z', 'http_url_to_repo': 'https://gitlab.com/fjy123/fwt.git', 'namespace': {'id': 3417900, 'name': 'fjy123', 'path': 'fjy123', 'full_path': 'fjy123', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T11:03:52.668Z'}
# {'tag_list': [], 'name': 'feature-test', 'readme_url': 'https://gitlab.com/prabhanshu/feature-test/blob/master/README.md', 'path': 'feature-test', 'web_url': 'https://gitlab.com/prabhanshu/feature-test', 'forks_count': 0, 'path_with_namespace': 'prabhanshu/feature-test', 'name_with_namespace': 'Prabhanshu Attri / feature-test', 'description': 'testing gitlab features', 'default_branch': 'master', 'id': 8868064, '_id': ObjectId('5bc4c92c4adcf67d12a18235'), 'ssh_url_to_repo': 'git@gitlab.com:prabhanshu/feature-test.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T09:46:01.097Z', 'http_url_to_repo': 'https://gitlab.com/prabhanshu/feature-test.git', 'namespace': {'id': 1371304, 'name': 'prabhanshu', 'path': 'prabhanshu', 'full_path': 'prabhanshu', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T09:46:01.097Z'}
# {'tag_list': [], 'name': 'FeedUp', 'readme_url': 'https://gitlab.com/e1337us3r/FeedUp/blob/master/README.md', 'path': 'FeedUp', 'web_url': 'https://gitlab.com/e1337us3r/FeedUp', 'forks_count': 0, 'path_with_namespace': 'e1337us3r/FeedUp', 'name_with_namespace': 'Sinan Sakaoğlu / FeedUp', 'description': None, 'default_branch': 'master', 'id': 8867907, '_id': ObjectId('5bc4c92d4adcf67d12a18236'), 'ssh_url_to_repo': 'git@gitlab.com:e1337us3r/FeedUp.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T09:37:28.706Z', 'http_url_to_repo': 'https://gitlab.com/e1337us3r/FeedUp.git', 'namespace': {'id': 3786616, 'name': 'e1337us3r', 'path': 'e1337us3r', 'full_path': 'e1337us3r', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T09:37:28.706Z'}
# {'tag_list': [], 'name': 'Factory Tech', 'readme_url': None, 'path': 'FactoryTech', 'web_url': 'https://gitlab.com/monotonehell/FactoryTech', 'forks_count': 0, 'path_with_namespace': 'monotonehell/FactoryTech', 'name_with_namespace': 'monotonehell / Factory Tech', 'description': 'Factory Tech, a tech mod centered around automatic maintenance of machines', 'default_branch': 'master', 'id': 8867903, '_id': ObjectId('5bc4c92d4adcf67d12a18237'), 'ssh_url_to_repo': 'git@gitlab.com:monotonehell/FactoryTech.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T09:37:17.726Z', 'http_url_to_repo': 'https://gitlab.com/monotonehell/FactoryTech.git', 'namespace': {'id': 3802017, 'name': 'monotonehell', 'path': 'monotonehell', 'full_path': 'monotonehell', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T09:37:17.726Z'}
# {'tag_list': [], 'name': 'frpCourse', 'readme_url': None, 'path': 'frpCourse', 'web_url': 'https://gitlab.com/kindlychung/frpCourse', 'forks_count': 0, 'path_with_namespace': 'kindlychung/frpCourse', 'name_with_namespace': 'Kaiyin Zhong / frpCourse', 'description': 'Principles of Reactive Programming slides and code', 'default_branch': 'master', 'id': 8867600, '_id': ObjectId('5bc4c9324adcf67d12a18238'), 'ssh_url_to_repo': 'git@gitlab.com:kindlychung/frpCourse.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T09:27:22.389Z', 'http_url_to_repo': 'https://gitlab.com/kindlychung/frpCourse.git', 'namespace': {'id': 633660, 'name': 'kindlychung', 'path': 'kindlychung', 'full_path': 'kindlychung', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T09:27:22.389Z'}
# {'tag_list': [], 'name': 'fswatch', 'readme_url': 'https://gitlab.com/kindlychung/fswatch/blob/master/README.md', 'path': 'fswatch', 'web_url': 'https://gitlab.com/kindlychung/fswatch', 'forks_count': 0, 'path_with_namespace': 'kindlychung/fswatch', 'name_with_namespace': 'Kaiyin Zhong / fswatch', 'description': "Monitor a directory for changes and run a shell command, using OS X's FSEvents API", 'default_branch': 'master', 'id': 8867566, '_id': ObjectId('5bc4c9384adcf67d12a18239'), 'ssh_url_to_repo': 'git@gitlab.com:kindlychung/fswatch.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T09:27:15.381Z', 'http_url_to_repo': 'https://gitlab.com/kindlychung/fswatch.git', 'namespace': {'id': 633660, 'name': 'kindlychung', 'path': 'kindlychung', 'full_path': 'kindlychung', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T09:27:15.381Z'}
# {'tag_list': [], 'name': 'fpRotterdamDojo', 'readme_url': 'https://gitlab.com/kindlychung/fpRotterdamDojo/blob/master/readme.md', 'path': 'fpRotterdamDojo', 'web_url': 'https://gitlab.com/kindlychung/fpRotterdamDojo', 'forks_count': 0, 'path_with_namespace': 'kindlychung/fpRotterdamDojo', 'name_with_namespace': 'Kaiyin Zhong / fpRotterdamDojo', 'description': '# Dojos from Functional Rotterdam meetup ', 'default_branch': 'master', 'id': 8867565, '_id': ObjectId('5bc4c9384adcf67d12a1823a'), 'ssh_url_to_repo': 'git@gitlab.com:kindlychung/fpRotterdamDojo.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T09:27:15.179Z', 'http_url_to_repo': 'https://gitlab.com/kindlychung/fpRotterdamDojo.git', 'namespace': {'id': 633660, 'name': 'kindlychung', 'path': 'kindlychung', 'full_path': 'kindlychung', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T09:27:15.179Z'}
# {'tag_list': [], 'name': 'Flickalz', 'readme_url': 'https://gitlab.com/kindlychung/Flickalz/blob/master/readme.md', 'path': 'Flickalz', 'web_url': 'https://gitlab.com/kindlychung/Flickalz', 'forks_count': 0, 'path_with_namespace': 'kindlychung/Flickalz', 'name_with_namespace': 'Kaiyin Zhong / Flickalz', 'description': "40 Hz flickering window to fight against Alzheimer's disease", 'default_branch': 'master', 'id': 8867564, '_id': ObjectId('5bc4c9384adcf67d12a1823b'), 'ssh_url_to_repo': 'git@gitlab.com:kindlychung/Flickalz.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T09:27:15.076Z', 'http_url_to_repo': 'https://gitlab.com/kindlychung/Flickalz.git', 'namespace': {'id': 633660, 'name': 'kindlychung', 'path': 'kindlychung', 'full_path': 'kindlychung', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T09:27:15.076Z'}
# {'tag_list': [], 'name': 'fppisc', 'readme_url': 'https://gitlab.com/kindlychung/fppisc/blob/master/readme.md', 'path': 'fppisc', 'web_url': 'https://gitlab.com/kindlychung/fppisc', 'forks_count': 0, 'path_with_namespace': 'kindlychung/fppisc', 'name_with_namespace': 'Kaiyin Zhong / fppisc', 'description': 'Source code for the book ÂŤFunctional Programming Patterns in Scala and ClojureÂť', 'default_branch': 'master', 'id': 8867561, '_id': ObjectId('5bc4c9394adcf67d12a1823c'), 'ssh_url_to_repo': 'git@gitlab.com:kindlychung/fppisc.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T09:27:15.024Z', 'http_url_to_repo': 'https://gitlab.com/kindlychung/fppisc.git', 'namespace': {'id': 633660, 'name': 'kindlychung', 'path': 'kindlychung', 'full_path': 'kindlychung', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T09:27:15.024Z'}
# {'tag_list': [], 'name': 'fpinscala', 'readme_url': 'https://gitlab.com/kindlychung/fpinscala/blob/master/README.md', 'path': 'fpinscala', 'web_url': 'https://gitlab.com/kindlychung/fpinscala', 'forks_count': 0, 'path_with_namespace': 'kindlychung/fpinscala', 'name_with_namespace': 'Kaiyin Zhong / fpinscala', 'description': 'Code, exercises, answers, and hints to go along with the book "Functional Programming in Scala"', 'default_branch': 'master', 'id': 8867562, '_id': ObjectId('5bc4c9394adcf67d12a1823d'), 'ssh_url_to_repo': 'git@gitlab.com:kindlychung/fpinscala.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T09:27:15.002Z', 'http_url_to_repo': 'https://gitlab.com/kindlychung/fpinscala.git', 'namespace': {'id': 633660, 'name': 'kindlychung', 'path': 'kindlychung', 'full_path': 'kindlychung', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T09:27:15.002Z'}
# {'tag_list': [], 'name': 'firstBigAppInJavaFx', 'readme_url': None, 'path': 'firstBigAppInJavaFx', 'web_url': 'https://gitlab.com/kindlychung/firstBigAppInJavaFx', 'forks_count': 0, 'path_with_namespace': 'kindlychung/firstBigAppInJavaFx', 'name_with_namespace': 'Kaiyin Zhong / firstBigAppInJavaFx', 'description': 'firstBigAppInJavaFx', 'default_branch': 'master', 'id': 8867559, '_id': ObjectId('5bc4c9394adcf67d12a1823e'), 'ssh_url_to_repo': 'git@gitlab.com:kindlychung/firstBigAppInJavaFx.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T09:27:14.311Z', 'http_url_to_repo': 'https://gitlab.com/kindlychung/firstBigAppInJavaFx.git', 'namespace': {'id': 633660, 'name': 'kindlychung', 'path': 'kindlychung', 'full_path': 'kindlychung', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T09:27:14.311Z'}
# {'preferred_support_url': '', 'video_url': '', 'summary': '', 'labels': [], 'screenshots': [], '_id': '515c53d8e88f3d0ab966307a', 'preferred_support_tool': '', 'short_description': 'Fanteris ® Sensiborte Application Project.\r\nUsing Huffman algorithm-based MDK file format, fast backup or encrypted data, encryption can also be used as the application calls.\r\n', 'forge': 'sourceforge', 'private': False, 'status': 'active', 'moved_to_url': '', 'creation_date': '2011-09-19', 'external_homepage': 'http://f-senapp.sourceforge.net', 'name': ' F-Sen Data', 'shortname': 'f-senapp', 'icon_url': None, 'tools': [{'mount_point': 'files', 'name': 'files', 'installable': False, 'url': '/p/f-senapp/files/', 'tool_label': 'Files', 'icons': {'32': 'images/downloads_32.png', '24': 'images/downloads_24.png', '48': 'images/downloads_48.png'}, 'mount_label': 'Files'}, {'sourceforge_group_id': 596374, 'mount_point': 'summary', 'name': 'summary', 'installable': False, 'url': '/p/f-senapp/summary/', 'tool_label': 'Summary', 'icons': {'32': 'images/sftheme/32x32/blog_32.png', '24': 'images/sftheme/24x24/blog_24.png', '48': 'images/sftheme/48x48/blog_48.png'}, 'mount_label': 'Summary'}, {'mount_point': 'wiki', 'name': 'wiki', 'installable': True, 'url': '/p/f-senapp/wiki/', 'tool_label': 'Wiki', 'icons': {'32': 'images/wiki_32.png', '24': 'images/wiki_24.png', '48': 'images/wiki_48.png'}, 'mount_label': 'Wiki'}, {'mount_point': 'support', 'name': 'support', 'installable': False, 'url': '/p/f-senapp/support/', 'tool_label': 'Support', 'icons': {'32': 'images/sftheme/32x32/blog_32.png', '24': 'images/sftheme/24x24/blog_24.png', '48': 'images/sftheme/48x48/blog_48.png'}, 'mount_label': 'Support'}, {'mount_point': 'reviews', 'name': 'reviews', 'installable': False, 'url': '/p/f-senapp/reviews/', 'tool_label': 'Reviews', 'icons': {'32': 'images/sftheme/32x32/blog_32.png', '24': 'images/sftheme/24x24/blog_24.png', '48': 'images/sftheme/48x48/blog_48.png'}, 'mount_label': 'Reviews'}, {'mount_point': 'activity', 'name': 'activity', 'installable': False, 'url': '/p/f-senapp/activity/', 'tool_label': 'Tool', 'icons': {'32': 'images/admin_32.png', '24': 'images/admin_24.png', '48': 'images/admin_48.png'}, 'mount_label': 'Activity'}, {'mount_point': 'mailman', 'name': 'mailman', 'installable': False, 'url': '/p/f-senapp/mailman/', 'tool_label': 'Mailing Lists', 'icons': {'32': 'images/forums_32.png', '24': 'images/forums_24.png', '48': 'images/forums_48.png'}, 'mount_label': 'Mailing Lists'}], 'categories': {'environment': [], 'language': [], 'developmentstatus': [], 'audience': [], 'database': [], 'topic': [], 'license': [], 'os': [], 'translation': []}, 'url': 'https://sourceforge.net/p/f-senapp/', 'developers': [], 'socialnetworks': []}
# ...
# {'tag_list': [], 'name': 'ansible-role-ntp', 'readme_url': 'https://gitlab.com/vbotka/ansible-role-ntp/blob/master/README.md', 'path': 'ansible-role-ntp', 'web_url': 'https://gitlab.com/vbotka/ansible-role-ntp', 'forks_count': 0, 'path_with_namespace': 'vbotka/ansible-role-ntp', 'name_with_namespace': 'Vladimir Botka / ansible-role-ntp', 'description': 'Ansible role. Configure ntp.', 'default_branch': 'master', 'id': 8874025, '_id': ObjectId('5bc4de5a4adcf67d12a182fb'), 'ssh_url_to_repo': 'git@gitlab.com:vbotka/ansible-role-ntp.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T14:54:58.598Z', 'http_url_to_repo': 'https://gitlab.com/vbotka/ansible-role-ntp.git', 'namespace': {'id': 3809998, 'name': 'vbotka', 'path': 'vbotka', 'full_path': 'vbotka', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T14:54:58.598Z'}
# {'tag_list': [], 'name': 'ansible-linux-postinstall', 'readme_url': 'https://gitlab.com/vbotka/ansible-linux-postinstall/blob/master/README.md', 'path': 'ansible-linux-postinstall', 'web_url': 'https://gitlab.com/vbotka/ansible-linux-postinstall', 'forks_count': 0, 'path_with_namespace': 'vbotka/ansible-linux-postinstall', 'name_with_namespace': 'Vladimir Botka / ansible-linux-postinstall', 'description': 'Ansible role. Post-install configuration of Linux.', 'default_branch': 'master', 'id': 8874023, '_id': ObjectId('5bc4de5b4adcf67d12a182fc'), 'ssh_url_to_repo': 'git@gitlab.com:vbotka/ansible-linux-postinstall.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T14:54:58.524Z', 'http_url_to_repo': 'https://gitlab.com/vbotka/ansible-linux-postinstall.git', 'namespace': {'id': 3809998, 'name': 'vbotka', 'path': 'vbotka', 'full_path': 'vbotka', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T14:54:58.524Z'}
# {'tag_list': [], 'name': 'ansible-openwrt-uci', 'readme_url': 'https://gitlab.com/vbotka/ansible-openwrt-uci/blob/master/README.md', 'path': 'ansible-openwrt-uci', 'web_url': 'https://gitlab.com/vbotka/ansible-openwrt-uci', 'forks_count': 0, 'path_with_namespace': 'vbotka/ansible-openwrt-uci', 'name_with_namespace': 'Vladimir Botka / ansible-openwrt-uci', 'description': 'ansible role for setting of uci config keys on openwrt systems', 'default_branch': 'master', 'id': 8874024, '_id': ObjectId('5bc4de5b4adcf67d12a182fd'), 'ssh_url_to_repo': 'git@gitlab.com:vbotka/ansible-openwrt-uci.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T14:54:58.496Z', 'http_url_to_repo': 'https://gitlab.com/vbotka/ansible-openwrt-uci.git', 'namespace': {'id': 3809998, 'name': 'vbotka', 'path': 'vbotka', 'full_path': 'vbotka', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T14:54:58.496Z'}
# {'tag_list': [], 'name': 'ansible-rcb', 'readme_url': 'https://gitlab.com/vbotka/ansible-rcb/blob/master/README.md', 'path': 'ansible-rcb', 'web_url': 'https://gitlab.com/vbotka/ansible-rcb', 'forks_count': 0, 'path_with_namespace': 'vbotka/ansible-rcb', 'name_with_namespace': 'Vladimir Botka / ansible-rcb', 'description': 'Ansible role. Install and configure RCB (Rsync-Crypto-Backup) github.com/vbotka/rcb.', 'default_branch': 'master', 'id': 8874022, '_id': ObjectId('5bc4de5b4adcf67d12a182fe'), 'ssh_url_to_repo': 'git@gitlab.com:vbotka/ansible-rcb.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T14:54:58.495Z', 'http_url_to_repo': 'https://gitlab.com/vbotka/ansible-rcb.git', 'namespace': {'id': 3809998, 'name': 'vbotka', 'path': 'vbotka', 'full_path': 'vbotka', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T14:54:58.495Z'}
# {'tag_list': [], 'name': 'ansible-role-docker', 'readme_url': 'https://gitlab.com/vbotka/ansible-role-docker/blob/master/README.md', 'path': 'ansible-role-docker', 'web_url': 'https://gitlab.com/vbotka/ansible-role-docker', 'forks_count': 0, 'path_with_namespace': 'vbotka/ansible-role-docker', 'name_with_namespace': 'Vladimir Botka / ansible-role-docker', 'description': 'Ansible role for installing Docker', 'default_branch': 'master', 'id': 8874021, '_id': ObjectId('5bc4de5b4adcf67d12a182ff'), 'ssh_url_to_repo': 'git@gitlab.com:vbotka/ansible-role-docker.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T14:54:58.490Z', 'http_url_to_repo': 'https://gitlab.com/vbotka/ansible-role-docker.git', 'namespace': {'id': 3809998, 'name': 'vbotka', 'path': 'vbotka', 'full_path': 'vbotka', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T14:54:58.490Z'}
# {'tag_list': [], 'name': 'ansible-leutils', 'readme_url': 'https://gitlab.com/vbotka/ansible-leutils/blob/master/README.md', 'path': 'ansible-leutils', 'web_url': 'https://gitlab.com/vbotka/ansible-leutils', 'forks_count': 0, 'path_with_namespace': 'vbotka/ansible-leutils', 'name_with_namespace': 'Vladimir Botka / ansible-leutils', 'description': 'Ansible role. Install le-utils from github.com/vbotka/le-utils and configure cron to email a list of certificates that will expire in specified number of days. Optionaly dry-run renewals. Optionaly renew if there are certificates due for renewal.', 'default_branch': 'master', 'id': 8874020, '_id': ObjectId('5bc4de5c4adcf67d12a18300'), 'ssh_url_to_repo': 'git@gitlab.com:vbotka/ansible-leutils.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T14:54:57.478Z', 'http_url_to_repo': 'https://gitlab.com/vbotka/ansible-leutils.git', 'namespace': {'id': 3809998, 'name': 'vbotka', 'path': 'vbotka', 'full_path': 'vbotka', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T14:54:57.478Z'}
# {'tag_list': [], 'name': 'ansible-integrity', 'readme_url': 'https://gitlab.com/vbotka/ansible-integrity/blob/master/README.md', 'path': 'ansible-integrity', 'web_url': 'https://gitlab.com/vbotka/ansible-integrity', 'forks_count': 0, 'path_with_namespace': 'vbotka/ansible-integrity', 'name_with_namespace': 'Vladimir Botka / ansible-integrity', 'description': 'Ansible.role. Install integrity from github.com/vbotka/integrity, record metadata (hash/mtree) of specified direcories and configure  cron to email alerts about inconsistencies.', 'default_branch': 'master', 'id': 8874019, '_id': ObjectId('5bc4de5c4adcf67d12a18301'), 'ssh_url_to_repo': 'git@gitlab.com:vbotka/ansible-integrity.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T14:54:57.332Z', 'http_url_to_repo': 'https://gitlab.com/vbotka/ansible-integrity.git', 'namespace': {'id': 3809998, 'name': 'vbotka', 'path': 'vbotka', 'full_path': 'vbotka', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T14:54:57.332Z'}
# {'tag_list': [], 'name': 'ansible-freebsd-zfs', 'readme_url': 'https://gitlab.com/vbotka/ansible-freebsd-zfs/blob/master/README.md', 'path': 'ansible-freebsd-zfs', 'web_url': 'https://gitlab.com/vbotka/ansible-freebsd-zfs', 'forks_count': 0, 'path_with_namespace': 'vbotka/ansible-freebsd-zfs', 'name_with_namespace': 'Vladimir Botka / ansible-freebsd-zfs', 'description': 'Ansible role. FreeBSD. Configure ZFS.', 'default_branch': 'master', 'id': 8874018, '_id': ObjectId('5bc4de5c4adcf67d12a18302'), 'ssh_url_to_repo': 'git@gitlab.com:vbotka/ansible-freebsd-zfs.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T14:54:57.276Z', 'http_url_to_repo': 'https://gitlab.com/vbotka/ansible-freebsd-zfs.git', 'namespace': {'id': 3809998, 'name': 'vbotka', 'path': 'vbotka', 'full_path': 'vbotka', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T14:54:57.276Z'}
# {'tag_list': [], 'name': 'ansible-freebsd-timezone', 'readme_url': 'https://gitlab.com/vbotka/ansible-freebsd-timezone/blob/master/README.md', 'path': 'ansible-freebsd-timezone', 'web_url': 'https://gitlab.com/vbotka/ansible-freebsd-timezone', 'forks_count': 0, 'path_with_namespace': 'vbotka/ansible-freebsd-timezone', 'name_with_namespace': 'Vladimir Botka / ansible-freebsd-timezone', 'description': 'Ansible role. Configure timezone in FreeBSD.', 'default_branch': 'master', 'id': 8874017, '_id': ObjectId('5bc4de5d4adcf67d12a18303'), 'ssh_url_to_repo': 'git@gitlab.com:vbotka/ansible-freebsd-timezone.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T14:54:57.179Z', 'http_url_to_repo': 'https://gitlab.com/vbotka/ansible-freebsd-timezone.git', 'namespace': {'id': 3809998, 'name': 'vbotka', 'path': 'vbotka', 'full_path': 'vbotka', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T14:54:57.179Z'}
# {'tag_list': [], 'name': 'ansible-freebsd-ssmtp', 'readme_url': 'https://gitlab.com/vbotka/ansible-freebsd-ssmtp/blob/master/README.md', 'path': 'ansible-freebsd-ssmtp', 'web_url': 'https://gitlab.com/vbotka/ansible-freebsd-ssmtp', 'forks_count': 0, 'path_with_namespace': 'vbotka/ansible-freebsd-ssmtp', 'name_with_namespace': 'Vladimir Botka / ansible-freebsd-ssmtp', 'description': 'Ansible role. FreeBSD. Install and configure SSMTP.', 'default_branch': 'master', 'id': 8874016, '_id': ObjectId('5bc4de5d4adcf67d12a18304'), 'ssh_url_to_repo': 'git@gitlab.com:vbotka/ansible-freebsd-ssmtp.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T14:54:56.982Z', 'http_url_to_repo': 'https://gitlab.com/vbotka/ansible-freebsd-ssmtp.git', 'namespace': {'id': 3809998, 'name': 'vbotka', 'path': 'vbotka', 'full_path': 'vbotka', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T14:54:56.982Z'}
# {'tag_list': [], 'name': 'ansible-freebsd-redis', 'readme_url': 'https://gitlab.com/vbotka/ansible-freebsd-redis/blob/master/README.md', 'path': 'ansible-freebsd-redis', 'web_url': 'https://gitlab.com/vbotka/ansible-freebsd-redis', 'forks_count': 0, 'path_with_namespace': 'vbotka/ansible-freebsd-redis', 'name_with_namespace': 'Vladimir Botka / ansible-freebsd-redis', 'description': 'Ansible role. FreeBSD. Install and configure Redis.', 'default_branch': 'master', 'id': 8874015, '_id': ObjectId('5bc4de5d4adcf67d12a18305'), 'ssh_url_to_repo': 'git@gitlab.com:vbotka/ansible-freebsd-redis.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T14:54:56.854Z', 'http_url_to_repo': 'https://gitlab.com/vbotka/ansible-freebsd-redis.git', 'namespace': {'id': 3809998, 'name': 'vbotka', 'path': 'vbotka', 'full_path': 'vbotka', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T14:54:56.854Z'}
# {'tag_list': [], 'name': 'ansible-freebsd-poudriere', 'readme_url': 'https://gitlab.com/vbotka/ansible-freebsd-poudriere/blob/master/README.md', 'path': 'ansible-freebsd-poudriere', 'web_url': 'https://gitlab.com/vbotka/ansible-freebsd-poudriere', 'forks_count': 0, 'path_with_namespace': 'vbotka/ansible-freebsd-poudriere', 'name_with_namespace': 'Vladimir Botka / ansible-freebsd-poudriere', 'description': 'Install and configure Poudriere Build System in FreeBSD.', 'default_branch': 'master', 'id': 8874014, '_id': ObjectId('5bc4de5e4adcf67d12a18306'), 'ssh_url_to_repo': 'git@gitlab.com:vbotka/ansible-freebsd-poudriere.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T14:54:56.703Z', 'http_url_to_repo': 'https://gitlab.com/vbotka/ansible-freebsd-poudriere.git', 'namespace': {'id': 3809998, 'name': 'vbotka', 'path': 'vbotka', 'full_path': 'vbotka', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T14:54:56.703Z'}
# {'tag_list': [], 'name': 'ansible-freebsd-postinstall', 'readme_url': 'https://gitlab.com/vbotka/ansible-freebsd-postinstall/blob/master/README.md', 'path': 'ansible-freebsd-postinstall', 'web_url': 'https://gitlab.com/vbotka/ansible-freebsd-postinstall', 'forks_count': 0, 'path_with_namespace': 'vbotka/ansible-freebsd-postinstall', 'name_with_namespace': 'Vladimir Botka / ansible-freebsd-postinstall', 'description': 'Ansible role. Post-install configuration of FreeBSD.', 'default_branch': 'master', 'id': 8874013, '_id': ObjectId('5bc4de5e4adcf67d12a18307'), 'ssh_url_to_repo': 'git@gitlab.com:vbotka/ansible-freebsd-postinstall.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T14:54:56.614Z', 'http_url_to_repo': 'https://gitlab.com/vbotka/ansible-freebsd-postinstall.git', 'namespace': {'id': 3809998, 'name': 'vbotka', 'path': 'vbotka', 'full_path': 'vbotka', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T14:54:56.614Z'}
# {'tag_list': [], 'name': 'ansible-freebsd-ports', 'readme_url': 'https://gitlab.com/vbotka/ansible-freebsd-ports/blob/master/README.md', 'path': 'ansible-freebsd-ports', 'web_url': 'https://gitlab.com/vbotka/ansible-freebsd-ports', 'forks_count': 0, 'path_with_namespace': 'vbotka/ansible-freebsd-ports', 'name_with_namespace': 'Vladimir Botka / ansible-freebsd-ports', 'description': 'Ansible role. Install and/or update ports at FreeBSD.', 'default_branch': 'master', 'id': 8874012, '_id': ObjectId('5bc4de5e4adcf67d12a18308'), 'ssh_url_to_repo': 'git@gitlab.com:vbotka/ansible-freebsd-ports.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T14:54:56.550Z', 'http_url_to_repo': 'https://gitlab.com/vbotka/ansible-freebsd-ports.git', 'namespace': {'id': 3809998, 'name': 'vbotka', 'path': 'vbotka', 'full_path': 'vbotka', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T14:54:56.550Z'}
# {'tag_list': [], 'name': 'ansible-freebsd-pf', 'readme_url': 'https://gitlab.com/vbotka/ansible-freebsd-pf/blob/master/README.md', 'path': 'ansible-freebsd-pf', 'web_url': 'https://gitlab.com/vbotka/ansible-freebsd-pf', 'forks_count': 0, 'path_with_namespace': 'vbotka/ansible-freebsd-pf', 'name_with_namespace': 'Vladimir Botka / ansible-freebsd-pf', 'description': 'Ansible role. Configure PF firewall in FreeBSD. ', 'default_branch': 'master', 'id': 8874011, '_id': ObjectId('5bc4de5e4adcf67d12a18309'), 'ssh_url_to_repo': 'git@gitlab.com:vbotka/ansible-freebsd-pf.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T14:54:56.400Z', 'http_url_to_repo': 'https://gitlab.com/vbotka/ansible-freebsd-pf.git', 'namespace': {'id': 3809998, 'name': 'vbotka', 'path': 'vbotka', 'full_path': 'vbotka', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T14:54:56.400Z'}
# {'tag_list': [], 'name': 'ansible-freebsd-packages', 'readme_url': 'https://gitlab.com/vbotka/ansible-freebsd-packages/blob/master/README.md', 'path': 'ansible-freebsd-packages', 'web_url': 'https://gitlab.com/vbotka/ansible-freebsd-packages', 'forks_count': 0, 'path_with_namespace': 'vbotka/ansible-freebsd-packages', 'name_with_namespace': 'Vladimir Botka / ansible-freebsd-packages', 'description': 'Configure package repositories and Install and/or Update packages on FreeBSD.', 'default_branch': 'master', 'id': 8874010, '_id': ObjectId('5bc4de5f4adcf67d12a1830a'), 'ssh_url_to_repo': 'git@gitlab.com:vbotka/ansible-freebsd-packages.git', 'star_count': 0, 'forge': 'gitlab', 'created_at': '2018-10-15T14:54:56.034Z', 'http_url_to_repo': 'https://gitlab.com/vbotka/ansible-freebsd-packages.git', 'namespace': {'id': 3809998, 'name': 'vbotka', 'path': 'vbotka', 'full_path': 'vbotka', 'kind': 'user', 'parent_id': None}, 'avatar_url': None, 'last_activity_at': '2018-10-15T14:54:56.034Z'}
